# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import metrics

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt

# %%
import pandas as pd
dataset = pd.read_csv('dataset_band_gap_features_selected.csv')
dataset.head()
# Out:
#   material_id formula  ...  frac d valence electrons  compound possible
# 0      mp-441   Rb2Te  ...                  0.555556               True
# 1    mp-22881   CdCl2  ...                  0.384615               True
# 2    mp-28013    MnI2  ...                  0.609756               True
# 3   mp-567290     LaN  ...                  0.125000               True
# 4   mp-560902    MnF2  ...                  0.238095               True
#
# [5 rows x 68 columns]

# %%
unwanted_columns = ['material_id', 'formula']
data = dataset
dataset = dataset.drop(unwanted_columns, axis=1)

dataset.head()
# Out:
#    band_gap      volume  ...  frac d valence electrons  compound possible
# 0      1.88  159.501208  ...                  0.555556               True
# 1      3.52   84.298097  ...                  0.384615               True
# 2      1.17  108.335875  ...                  0.609756               True
# 3      1.12   88.162562  ...                  0.125000               True
# 4      2.87   82.826401  ...                  0.238095               True
#
# [5 rows x 66 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x = dataset.drop(columns='band_gap',axis=1)
X = x.values
X = scaler.fit_transform(X)
y = dataset['band_gap'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
reg = ExtraTreesRegressor(n_estimators=200, random_state=1).fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.ylabel('Bandgap Energy (eV)')
plt.show()

# %%
print('R^2               :', np.sqrt(metrics.r2_score(y_test, y_pred)))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2               : 0.9477994306970087
# Mean Absolute Error: 0.3460922779922781
# Mean Squared Error: 0.23499612654440163
# Root Mean Squared Error: 0.4847639905607693

# %%
plt.figure(figsize=(7,7))
plt.scatter(y_test, y_pred)
plt.xlabel('DFT Calculations (eV)')
plt.ylabel('Predictions (eV)')
lims = [0, 8]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = y_pred - y_test
plt.hist(error, bins = 20)
plt.xlabel("MAE (eV)")
_ = plt.ylabel("Count")
